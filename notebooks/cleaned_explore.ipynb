# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('../data/FundDatawithMonthlyPrices.csv')
print(data.shape)
# Out:
# (461, 87)

# %%
data.groupby('aafmCategory').count().iloc[:, 1]
# Out:
# aafmCategory
# Accionario America Latina                                                                         14
# Accionario Asia Emergente                                                                          9
# Accionario Asia Pacifico                                                                           1
# Accionario Brasil                                                                                  8
# Accionario Desarrollado                                                                           14
# Accionario EEUU                                                                                   15
# Accionario Emergente                                                                              18
# Accionario Europa Desarrollado                                                                     9
# Accionario Europa Emergente                                                                        2
# ...

# %%
data.groupby('svsCategory').count().iloc[:, 1]
# Out:
# svsCategory
# FM DE INV.EN INST.DE DEUDA DE C/P CON DURACION <= 365 DIAS     28
# FM DE INV.EN INST.DE DEUDA DE C/P CON DURACION <= 90 DIAS      49
# FM DE INV.EN INST.DE DEUDA DE MEDIANO Y LARGO PLAZO            77
# FM DE INVERSION EN INSTRUMENTOS DE CAPITALIZACION              97
# FM DE LIBRE INVERSION                                         150
# FM DIRIGIDO A INVERSIONISTAS CALIFICADOS                       19
# FM ESTRUCTURADO                                                 1
# FM MIXTO                                                       37
# Name: fundRUN, dtype: int64

# %%
check_na = data.columns[14:]
data.dropna(subset=check_na).shape
# Out:
# (142, 87)

# %%
data.dropna(subset=check_na).groupby('aafmCategory').count().iloc[:, 1]
# Out:
# aafmCategory
# Accionario America Latina                                              5
# Accionario Asia Emergente                                              4
# Accionario Asia Pacifico                                               1
# Accionario Brasil                                                      1
# Accionario Desarrollado                                                6
# Accionario EEUU                                                        6
# Accionario Emergente                                                   4
# Accionario Europa Desarrollado                                         2
# Accionario Europa Emergente                                            1
# Accionario Nacional Large CAP                                         10
# Accionario Nacional Otros                                              2
# Accionario Pa�ses MILA                                                 1
# Accionario Sectorial                                                   1
# ...

# %%
data.dropna(subset=check_na).groupby('svsCategory').count().iloc[:, 1]
# Out:
# svsCategory
# FM DE INV.EN INST.DE DEUDA DE C/P CON DURACION <= 365 DIAS    10
# FM DE INV.EN INST.DE DEUDA DE C/P CON DURACION <= 90 DIAS     20
# FM DE INV.EN INST.DE DEUDA DE MEDIANO Y LARGO PLAZO           34
# FM DE INVERSION EN INSTRUMENTOS DE CAPITALIZACION             26
# FM DE LIBRE INVERSION                                         39
# FM DIRIGIDO A INVERSIONISTAS CALIFICADOS                       1
# FM MIXTO                                                      12
# Name: fundRUN, dtype: int64

# %%
funds = data.iloc[:, 1:10]
funds.head()
# Out:
#   fundRUN             fundName fundSeries bloombergCode APV  \
# 0  8812-9  A. CHILE CALIFICADO          A    ACCHICA CI  NO
# 1  8162-0        AC EMERGENTES          A    CORPASI CI  NO
# 2  8587-1    ACCIONES CHILENAS          A    A18TERA CI  NO
# 3  8247-3       ACCIONES LATAM          A    EUCAPIA CI  NO
# 4  8872-2  ACCIONES NACIONALES          A    LARVIPI CI  NO
#
#                                      aafmCategory  \
# 0  Inversionistas Calificados Accionario Nacional
# 1                            Accionario Emergente
# 2                   Accionario Nacional Large CAP
# 3                       Accionario America Latina
# 4                   Accionario Nacional Large CAP
#
#                                          svsCategory  svsCategoryId currency
# 0           FM DIRIGIDO A INVERSIONISTAS CALIFICADOS            8.0        P
# 1  FM DE INVERSION EN INSTRUMENTOS DE CAPITALIZACION            5.0        P
# ...

# %%
prices = data.iloc[:, 14:]
prices.head()
# Out:
#    1/31/2015  2/28/2015  3/31/2015  4/30/2015  5/31/2015  6/30/2015  \
# 0  1000.0000  1000.0000  1000.0000  1000.0000  1000.0000  1000.0000
# 1   898.5420   890.6828   903.2852   926.1299   921.3001   917.9266
# 2   946.4151   971.2197   966.3604   976.9819   957.9090   913.3021
# 3  1693.6139  1722.7516  1635.1843  1717.7214  1632.6834  1666.3880
# 4  2310.2509  2382.9152  2355.5203  2401.0723  2379.6895  2285.4300
#
#    7/31/2015  8/31/2015  9/30/2015  10/31/2015  ...  4/30/2020  5/31/2020  \
# 0  1000.0000  1000.0000  1000.0000   1000.0000  ...  1000.0000  1000.0000
# 1   919.2881   866.7555   850.5335    894.4375  ...        NaN        NaN
# 2   897.2501   891.8716   868.2392    887.6627  ...        NaN        NaN
# 3  1624.6163  1502.2527  1425.8536   1501.3926  ...  1397.8727  1480.2771
# 4  2281.0280  2256.0428  2182.9294   2234.7436  ...  1766.1687  1638.2794
#
#    6/30/2020  7/31/2020  8/31/2020  9/30/2020  10/31/2020  11/30/2020  \
# ...

# %%
prices.dropna().shape
# Out:
# (142, 73)

# %%
prices = prices.T
prices.index = pd.to_datetime(prices.index)
prices.head()
# Out:
#                0         1         2          3          4          5    \
# 2015-01-31  1000.0  898.5420  946.4151  1693.6139  2310.2509  1268.8118
# 2015-02-28  1000.0  890.6828  971.2197  1722.7516  2382.9152  1290.0886
# 2015-03-31  1000.0  903.2852  966.3604  1635.1843  2355.5203  1289.0306
# 2015-04-30  1000.0  926.1299  976.9819  1717.7214  2401.0723  1277.8355
# 2015-05-31  1000.0  921.3001  957.9090  1632.6834  2379.6895  1283.8804
#
#                   6          7          8         9    ...        451  452  \
# 2015-01-31  1101.4274  1144.2227  1168.5585  499.9075  ...  1377.6358  NaN
# 2015-02-28  1115.8103  1153.7850  1169.5390  516.7131  ...  1379.3441  NaN
# 2015-03-31  1117.2210  1153.3668  1169.4502  511.3597  ...  1383.6375  NaN
# 2015-04-30  1102.7034  1139.2270  1171.1882  505.4209  ...  1386.0338  NaN
# 2015-05-31  1107.4667  1146.2572  1172.4196  509.5354  ...  1390.1447  NaN
#
#             453       454       455       456        457        458       459  \
# ...

# %%
prices.pct_change()
# Out:
#             0         1         2         3         4         5         6    \
# 2015-01-31  NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-02-28  0.0 -0.008747  0.026209  0.017204  0.031453  0.016769  0.013058
# 2015-03-31  0.0  0.014149 -0.005003 -0.050830 -0.011496 -0.000820  0.001264
# 2015-04-30  0.0  0.025291  0.010991  0.050476  0.019338 -0.008685 -0.012994
# 2015-05-31  0.0 -0.005215 -0.019522 -0.049506 -0.008906  0.004731  0.004320
# ...         ...       ...       ...       ...       ...       ...       ...
# 2020-09-30  0.0  0.000000  0.000000 -0.065448 -0.038811 -0.014576 -0.014131
# 2020-10-31  0.0  0.000000  0.000000 -0.019082 -0.038274 -0.032137 -0.015180
# 2020-11-30  0.0  0.000000  0.000000  0.213664  0.132846  0.078579  0.047148
# 2020-12-31  0.0  0.000000  0.000000  0.006958  0.040471 -0.019531 -0.012316
# 2021-01-31  0.0  0.000000  0.000000 -0.017005  0.025394  0.026788  0.018407
#
# ...

# %%
prices = prices.pct_change().T
prices = prices.replace([-np.inf, np.inf], np.nan)
prices.head()
# Out:
#    2015-01-31  2015-02-28  2015-03-31  2015-04-30  2015-05-31  2015-06-30  \
# 0         NaN    0.000000    0.000000    0.000000    0.000000    0.000000
# 1         NaN   -0.008747    0.014149    0.025291   -0.005215   -0.003662
# 2         NaN    0.026209   -0.005003    0.010991   -0.019522   -0.046567
# 3         NaN    0.017204   -0.050830    0.050476   -0.049506    0.020644
# 4         NaN    0.031453   -0.011496    0.019338   -0.008906   -0.039610
#
#    2015-07-31  2015-08-31  2015-09-30  2015-10-31  ...  2020-04-30  \
# 0    0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 1    0.001483   -0.057145   -0.018716    0.051619  ...    0.000000
# 2   -0.017576   -0.005994   -0.026498    0.022371  ...    0.000000
# 3   -0.025067   -0.075318   -0.050856    0.052978  ...    0.035468
# 4   -0.001926   -0.010953   -0.032408    0.023736  ...    0.149527
#
#    2020-05-31  2020-06-30  2020-07-31  2020-08-31  2020-09-30  2020-10-31  \
# ...

# %%
prices.columns = [x.strftime('%Y-%m-%d') for x in prices.columns]

# %%
data = pd.concat([funds, prices], axis=1)
data.to_csv('../data/FundDatawithMonthlyPctChanges.csv')

# %%
data.iloc[:, 9:].isna().sum().sum()
# Out:
# 0

# %%
np.isinf(data.iloc[:, 9:]).sum().sum()
# Out:
# 0
