# %%
import pandas as pd
from dva.fund_returns import (
    get_static_data, get_price_data, get_return_data, make_dataset, get_category_means, fill_series, fill_na
)

# %%
data = pd.read_csv('../data/FundDataWithMonthlyPrices_v3.csv')

# %%
static = get_static_data(data)
static
# Out:
#     fundRUN              fundName fundSeries  \
# 0    8812-9   A. CHILE CALIFICADO          D
# 1    8289-9        ACCIONES CHILE        APV
# 2    8076-4     ACCIONES CHILENAS        APV
# 3    9254-1       ACCIONES EUROPA       ALTO
# 4    8247-3        ACCIONES LATAM          A
# ..      ...                   ...        ...
# 306  8304-6            VALOR PLUS          A
# 307  8991-5         VALOR PLUS UF      PERSO
# 308  8011-K   VISION MONEY MARKET        100
# 309  8346-1     ZURICH PATRIMONIO          A
# 310  8621-5  ZURICH SELECT GLOBAL          A
#
#                                           aafmCategory  \
# 0       Inversionistas Calificados Accionario Nacional
# 1                        Accionario Nacional Large CAP
# 2                        Accionario Nacional Large CAP
# 3                       Accionario Europa Desarrollado
# 4                            Accionario America Latina
# ..                                                 ...
# ...

# %%
prices = get_price_data(data)
prices
# Out:
#         1/31/15     2/28/15     3/31/15     4/30/15     5/31/15     6/30/15  \
# 0      767.0540    788.5753    785.9268    797.9719    792.9950    763.2672
# 1      857.0135    882.9958    873.0740    882.3608    874.7575    840.6924
# 2     4264.7434   4467.0361   4386.0161   4499.4617   4429.9785   4233.6025
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4     1693.6139   1722.7516   1635.1843   1717.7214   1632.6834   1666.3880
# ..          ...         ...         ...         ...         ...         ...
# 306   1634.0381   1640.8835   1643.6302   1647.2129   1653.3580   1659.8571
# 307         NaN         NaN         NaN         NaN         NaN         NaN
# 308  28476.9327  28546.6508  28621.2591  28697.0684  28776.6986  28849.4038
# 309   1376.8601   1390.0569   1399.5459   1386.3464   1392.5871   1401.2721
# 310   1600.2140   1649.5923   1652.2255   1633.9630   1659.2681   1661.0704
#
# ...

# %%
returns = get_return_data(prices)
returns
# Out:
#      2015-01-31  2015-02-28  2015-03-31  2015-04-30  2015-05-31  2015-06-30  \
# 0           NaN    0.028057   -0.003359    0.015326   -0.006237   -0.037488
# 1           NaN    0.030317   -0.011237    0.010637   -0.008617   -0.038942
# 2           NaN    0.047434   -0.018137    0.025865   -0.015443   -0.044329
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN    0.017204   -0.050830    0.050476   -0.049506    0.020644
# ..          ...         ...         ...         ...         ...         ...
# 306         NaN    0.004189    0.001674    0.002180    0.003731    0.003931
# 307         NaN         NaN         NaN         NaN         NaN         NaN
# 308         NaN    0.002448    0.002614    0.002649    0.002775    0.002527
# 309         NaN    0.009585    0.006826   -0.009431    0.004502    0.006237
# 310         NaN    0.030857    0.001596   -0.011053    0.015487    0.001086
#
# ...

# %%
data = make_dataset(static, returns)
data
# Out:
#     fundRUN              fundName fundSeries  \
# 0    8812-9   A. CHILE CALIFICADO          D
# 1    8289-9        ACCIONES CHILE        APV
# 2    8076-4     ACCIONES CHILENAS        APV
# 3    9254-1       ACCIONES EUROPA       ALTO
# 4    8247-3        ACCIONES LATAM          A
# ..      ...                   ...        ...
# 306  8304-6            VALOR PLUS          A
# 307  8991-5         VALOR PLUS UF      PERSO
# 308  8011-K   VISION MONEY MARKET        100
# 309  8346-1     ZURICH PATRIMONIO          A
# 310  8621-5  ZURICH SELECT GLOBAL          A
#
#                                           aafmCategory  \
# 0       Inversionistas Calificados Accionario Nacional
# 1                        Accionario Nacional Large CAP
# 2                        Accionario Nacional Large CAP
# 3                       Accionario Europa Desarrollado
# 4                            Accionario America Latina
# ..                                                 ...
# ...

# %%
cat_means = get_category_means(data)
filled = fill_na(data, cat_means)
filled
# Out:
#     fundRUN              fundName fundSeries  \
# 0    8812-9   A. CHILE CALIFICADO          D
# 1    8289-9        ACCIONES CHILE        APV
# 2    8076-4     ACCIONES CHILENAS        APV
# 3    9254-1       ACCIONES EUROPA       ALTO
# 4    8247-3        ACCIONES LATAM          A
# ..      ...                   ...        ...
# 306  8304-6            VALOR PLUS          A
# 307  8991-5         VALOR PLUS UF      PERSO
# 308  8011-K   VISION MONEY MARKET        100
# 309  8346-1     ZURICH PATRIMONIO          A
# 310  8621-5  ZURICH SELECT GLOBAL          A
#
#                                           aafmCategory  \
# 0       Inversionistas Calificados Accionario Nacional
# 1                        Accionario Nacional Large CAP
# 2                        Accionario Nacional Large CAP
# 3                       Accionario Europa Desarrollado
# 4                            Accionario America Latina
# ..                                                 ...
# ...

# %%
filled.to_csv('../data/monthly_returns.csv')
